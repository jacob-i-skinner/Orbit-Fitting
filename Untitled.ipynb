# %%
import time
t0 = time.time()
import numpy as np
import emcee
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt
# %matplotlib inline
y = np.random.randn(10000)
x = np.linspace(-5,5,num = 10000)
plt.hist(y, bins = 20)
# Out:
# (array([  1.00000000e+00,   3.00000000e+00,   1.50000000e+01,
#           5.10000000e+01,   1.01000000e+02,   2.75000000e+02,
#           5.36000000e+02,   8.96000000e+02,   1.24200000e+03,
#           1.54500000e+03,   1.61400000e+03,   1.41600000e+03,
#           1.02300000e+03,   6.73000000e+02,   3.67000000e+02,
#           1.52000000e+02,   6.00000000e+01,   2.40000000e+01,
#           4.00000000e+00,   2.00000000e+00]),
#  array([-4.1772923 , -3.76927515, -3.36125799, -2.95324083, -2.54522367,
#         -2.13720652, -1.72918936, -1.3211722 , -0.91315505, -0.50513789,
#         -0.09712073,  0.31089643,  0.71891358,  1.12693074,  1.5349479 ,
#          1.94296506,  2.35098221,  2.75899937,  3.16701653,  3.57503368,
#          3.98305084]),
#  <a list of 20 Patch objects>)

# %%
[np.random.randn(6) for i in range(200)]
# Out:
# [array([-0.12996628,  1.23383436,  0.0298103 ,  0.30037352, -1.4234773 ,
#          1.02285984]),
#  array([-1.3213737 , -0.27443679, -0.28646358, -0.51017137, -1.51617764,
#          0.63148229]),
#  array([-0.24737586, -0.341377  , -0.49716021, -0.65919743,  0.77650828,
#          0.6638551 ]),
#  array([ 0.11855724,  0.4109734 ,  0.09118284,  0.37609457, -0.61625578,
#         -0.61245915]),
#  array([ 0.07034244, -0.19697137,  1.37343423,  0.95041131,  0.17242912,
#         -1.06769028]),
#  array([ 0.21034779,  1.39326137,  1.27480333, -0.68486164,  0.41206716,
#          2.8787338 ]),
#  array([-2.59642799,  0.86568467, -0.40913261,  0.51662046, -0.16506345,
#         -1.77642971]),
#  array([ 0.98327986, -1.00085395,  0.01815505,  0.79732209,  0.66646658,
#         -1.76655266]),
#  array([-0.34561771, -0.83687479,  0.41913745,  1.34176707, -0.11386059,
#         -0.31714693]),
#  array([ 0.88424598, -1.9840386 , -0.83049647,  1.82037077, -1.98862077,
#         -0.03458793]),
# ...
